# %%
import pandas as pd
import requests

url = "https://coinstats.app/"

r = requests.get(url)
df_list = pd.read_html(r.text) 
df = df_list[0]
df.head(20)
# Out:
#      #                     Name 24h Change      Price  Price in BTC  \
# 0    1            Bitcoin • BTC     -1.55%    $36,295      1.000000
# 1    2           Ethereum • ETH      1.68%  $2,582.79      0.071153
# 2    3            Tether • USDT     -0.03%  $0.999909      0.000028
# 3    4            Cardano • ADA      2.13%      $1.72      0.000047
# 4    5       Binance Coin • BNB      0.70%     $348.8      0.009609
# 5    6                XRP • XRP      0.46%      $1.01      0.000028
# 6    7          Dogecoin • DOGE      3.50%  $0.322733      0.000009
# 7    8          USD Coin • USDC      0.40%  $0.999076      0.000027
# 8    9           Polkadot • DOT      3.20%     $22.29      0.000614
# 9   10            Uniswap • UNI      2.58%     $26.96      0.000743
# 10  11  Internet Computer • ICP     -2.44%    $109.21      0.003008
# 11  12         Chainlink • LINK      3.99%     $30.04      0.000827
# 12  13       Bitcoin Cash • BCH     -0.85%    $681.03      0.018762
# ...

# %%
# Out:
#    #           Name 24h Change      Price  Price in BTC Market Cap Volume 24h  \
# 2  3  Tether • USDT     -0.03%  $0.999909      0.000028     $62.0B    $170.0B
#
#    Price Graph (7D)  Unnamed: 8
# 2               NaN         NaN
